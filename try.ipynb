# %% [markdown]
# $$ \LaTeX \text{ command declarations here.}
# \newcommand{\R}{\mathbb{R}}
# \renewcommand{\vec}[1]{\mathbf{#1}}
# \newcommand{\X}{\mathcal{X}}
# \newcommand{\D}{\mathcal{D}}
# \newcommand{\G}{\mathcal{G}}
# \newcommand{\L}{\mathcal{L}}
# \newcommand{\X}{\mathcal{X}}
# \newcommand{\Parents}{\mathrm{Parents}}
# \newcommand{\NonDesc}{\mathrm{NonDesc}}
# \newcommand{\I}{\mathcal{I}}
# \newcommand{\dsep}{\text{d-sep}}
# \newcommand{\Cat}{\mathrm{Categorical}}
# \newcommand{\Bin}{\mathrm{Binomial}}
# $$

# %%
import pandas as pd

pred = pd.read_csv("yt8m_train_video_level_logistic_model%2Fpredictions.csv", nrows=20)

pred
# Out:
#       VideoId                               LabelConfidencePairs
# 0   100011194  1 0.925126 4 0.899683 0 0.753539 2 0.666526 16...
# 1   100253546  77 0.808040 21 0.528455 112 0.242232 59 0.1588...
# 2   100347260  46 0.526787 7 0.450689 3 0.290358 13 0.251195 ...
# 3   100436527  1 0.319669 85 0.056566 62 0.048803 4 0.044578 ...
# 4   100573509  7 0.612388 14 0.446310 13 0.297301 24 0.115052...
# 5   100122848  20 0.937359 387 0.393417 2 0.115211 89 0.11369...
# 6   100306012  2 0.901047 0 0.895097 34 0.220904 237 0.087376...
# 7   100404872  49 0.214890 102 0.182221 209 0.169520 162 0.11...
# 8   100049134  142 0.888252 112 0.523548 0 0.514671 59 0.3158...
# 9   100311706  8 0.962734 0 0.525210 73 0.334329 65 0.332208 ...
# 10  100007070  56 0.594928 106 0.387127 6 0.131027 340 0.0874...
# 11  100445434  8 0.838749 0 0.146558 21 0.112817 54 0.070199 ...
# 12  100085312  5 0.615729 3 0.104485 13 0.091459 16 0.084679 ...
# 13  100319764  6 0.164131 260 0.086382 1 0.064437 15 0.046255...
# 14  100041402  1 0.961287 4 0.820238 11 0.238915 167 0.096240...
# 15  100301065  8 0.409932 18 0.193114 0 0.083408 463 0.062352...
# 16  100176684  78 0.994196 190 0.915474 9 0.358019 590 0.2498...
# 17  100046077  61 0.352609 9 0.146273 1 0.096899 148 0.084164...
# 18  100303689  1 0.999292 124 0.996724 156 0.976107 174 0.870...
# 19  100019665  3 0.960035 13 0.833060 7 0.636859 16 0.584234 ...
